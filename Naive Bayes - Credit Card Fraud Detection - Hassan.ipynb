# %% [markdown]
# # CODE TO DETECT CREDIT CARD FRAUD DETECTION USING NAIVE BAYES

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# - Credit card companies need to have the ability to recognize fraudulent credit card transactions so that customers are not charged for items that they did not purchase.
#
# - Datasets contains transactions made by credit cards in September 2013 by european cardholders. This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# - The data contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data.
#
# - Input Features: V1, V2, ... V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning.
#
# - Output: 1 in case of fraud and 0 otherwise.
# - Link to the dataset: https://www.kaggle.com/mlg-ulb/creditcardfraud/home

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # STEP #0: LIBRARIES IMPORT

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # STEP #1: IMPORT DATASET

# %%
pd.set_option('display.max_rows', 20)

# %%
fraud = pd.read_csv('creditcard.csv')

# %%
fraud
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud.tail(5)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
fraud.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
fraud.keys()
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# # STEP #2: VISUALIZE DATASET

# %%
fraud_True = fraud[fraud['Class'] == 1]

# %%
fraud_True
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
fraud_False = fraud[fraud['Class'] == 0]

# %%
fraud_False
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
print('fraud transaction percentage = ', len(fraud_True)/len(fraud) * 100, '%')
# Out:
# fraud transaction percentage =  0.1727485630620034 %

# %%
sns.countplot(x = fraud['Class'], label = 'count')

# %%
plt.figure(figsize=(30,10))
sns.heatmap(fraud.corr(), annot=True)

# %%
column_headers = fraud.columns.values

# %%
# kernel density estimation (KDE) is a non-parametric way to estimate the probability density function of a random variable.
i = 1

fig, ax = plt.subplots(8,4,figsize=(18,30))
for column_header in column_headers:    
    plt.subplot(8,4,i)
    sns.kdeplot(fraud_True[column_header], bw = 0.4, label = "Fraud", shade=True, color="r", linestyle="--")
    sns.kdeplot(fraud_False[column_header], bw = 0.4, label = "Non Fraud", shade=True, color= "y", linestyle=":")
    plt.title(column_header, fontsize=12)
    i = i + 1
plt.show();
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:283: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # STEP #3: CREATE TESTING AND TRAINING DATASET/DATA CLEANING

# %%
# Feature Scale/Normalize the 'Amount' Column

# %%
amount_min = fraud['Amount'].min()

# %%
amount_min
# Out:
# 0.0

# %%
amount_max = fraud['Amount'].max()

# %%
amount_max
# Out:
# 25691.16

# %%
range_amount = amount_max - amount_min

# %%
range_amount
# Out:
# 25691.16

# %%
amount_normalize = (fraud['Amount'] - amount_min) / (range_amount)

# %%
amount_normalize
# Out:
# 0         0.005824
# 1         0.000105
# 2         0.014739
# 3         0.004807
# 4         0.002724
#             ...
# 284802    0.000030
# 284803    0.000965
# 284804    0.002642
# 284805    0.000389
# 284806    0.008446
# Name: Amount, Length: 284807, dtype: float64

# %%
# Let's drop the target label coloumns
fraud = fraud.drop(['Amount'], axis = 1)

# %%
X = fraud.drop(['Class'], axis =1)

# %%
X = pd.concat([X, amount_normalize], axis =1)

# %%
X
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y = fraud['Class']

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
# Divide the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (227845, 30)

# %%
X_test.shape
# Out:
# (56962, 30)

# %%
y_train.shape
# Out:
# (227845,)

# %%
y_test.shape
# Out:
# (56962,)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gaussian_classifier = GaussianNB()

# %%
gaussian_classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# # STEP#4: TRAINING THE MODEL

# %%
y_predict_train = gaussian_classifier.predict(X_train)

# %%
y_predict_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ### These are really bad results, we will improve them later.

# %%
print(classification_report(y_train, y_predict_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    227456
#            1       0.15      0.64      0.24       389
#
#     accuracy                           0.99    227845
#    macro avg       0.57      0.82      0.62    227845
# weighted avg       1.00      0.99      1.00    227845

# %% [markdown]
# ### Now, for the testing data sets

# %%
y_predict_test = gaussian_classifier.predict(X_test)

# %%
y_predict_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # STEP#5: EVALUATING THE MODEL

# %%
# Predict the training set results
cm = confusion_matrix(y_train, y_predict_train)
sns.heatmap(cm, annot=True)
print(classification_report(y_train, y_predict_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00    227456
#            1       0.15      0.64      0.24       389
#
#     accuracy                           0.99    227845
#    macro avg       0.57      0.82      0.62    227845
# weighted avg       1.00      0.99      1.00    227845

# %%
# Predicting the Test set results
cm = confusion_matrix(y_test, y_predict_test)
sns.heatmap(cm, annot=True)
print(classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56859
#            1       0.16      0.69      0.26       103
#
#     accuracy                           0.99     56962
#    macro avg       0.58      0.84      0.63     56962
# weighted avg       1.00      0.99      1.00     56962

# %% [markdown]
# # STEP#6: IMPROVING THE MODEL

# %%
# Drop similar features columns
X = fraud.drop(['Time', 'V2', 'V8', 'V13', 'V15', 'V20', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Class'], axis =1)

# %%
X
# Out:
#                V1        V3        V4        V5        V6        V7        V9  \
# 0       -1.359807  2.536347  1.378155 -0.338321  0.462388  0.239599  0.363787
# 1        1.191857  0.166480  0.448154  0.060018 -0.082361 -0.078803 -0.255425
# 2       -1.358354  1.773209  0.379780 -0.503198  1.800499  0.791461 -1.514654
# 3       -0.966272  1.792993 -0.863291 -0.010309  1.247203  0.237609 -1.387024
# 4       -1.158233  1.548718  0.403034 -0.407193  0.095921  0.592941  0.817739
# ...           ...       ...       ...       ...       ...       ...       ...
# 284802 -11.881118 -9.834783 -2.066656 -5.364473 -2.606837 -4.918215  1.914428
# 284803  -0.732789  2.035030 -0.738589  0.868229  1.058415  0.024330  0.584800
# 284804   1.919565 -3.249640 -0.557828  2.630515  3.031260 -0.296827  0.432454
# 284805  -0.240440  0.702510  0.689799 -0.377961  0.623708 -0.686180  0.392087
# 284806  -0.533413  0.703337 -0.506271 -0.012546 -0.649617  1.577006  0.486180
#
# ...

# %%
y = fraud['Class']

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (227845, 16)

# %%
X_test.shape
# Out:
# (56962, 16)

# %%
y_train.shape
# Out:
# (227845,)

# %%
y_test.shape
# Out:
# (56962,)

# %%
# Train the classifier again!

# %%
gaussian_classifier_improved = GaussianNB()

# %%
gaussian_classifier_improved.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_predict_train = gaussian_classifier_improved.predict(X_train)

# %%
y_predict_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
cm = confusion_matrix(y_train, y_predict_train)
sns.heatmap(cm, annot=True)
print(classification_report(y_train, y_predict_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    227449
#            1       0.10      0.85      0.17       396
#
#     accuracy                           0.99    227845
#    macro avg       0.55      0.92      0.58    227845
# weighted avg       1.00      0.99      0.99    227845

# %%
y_predict_test = gaussian_classifier_improved.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_predict_test)
sns.heatmap(cm, annot=True)
print(classification_report(y_test, y_predict_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56866
#            1       0.09      0.88      0.17        96
#
#     accuracy                           0.99     56962
#    macro avg       0.55      0.93      0.58     56962
# weighted avg       1.00      0.99      0.99     56962

# %%
print("Number of fraud points in the testing dataset = ", sum(y_test))
# Out:
# Number of fraud points in the testing dataset =  96

# %% [markdown]
# # EXCELLENT JOB! NOW YOU BECAME FAMILIAR WITH NAIVE BAYES, GREAT JOB!
